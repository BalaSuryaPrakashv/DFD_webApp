# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
! pip install pyngrok
# !pip install flask_ngrok
# !pip3 install face_recognition
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyngrok
#   Downloading pyngrok-7.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting PyYAML>=5.1 (from pyngrok)
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Downloading pyngrok-7.2.0-py3-none-any.whl (22 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
#    ---------------------------------------- 0.0/156.3 kB ? eta -:--:--
#    ------- -------------------------------- 30.7/156.3 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  153.6/156.3 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 156.3/156.3 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: PyYAML, pyngrok
# Successfully installed PyYAML-6.0.2 pyngrok-7.2.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\vbala\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting flask_ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: Flask>=0.8 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from flask_ngrok) (3.0.3)
# Requirement already satisfied: requests in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from flask_ngrok) (2.31.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask>=0.8->flask_ngrok) (3.0.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask>=0.8->flask_ngrok) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask>=0.8->flask_ngrok) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask>=0.8->flask_ngrok) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask>=0.8->flask_ngrok) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->flask_ngrok) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->flask_ngrok) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->flask_ngrok) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->flask_ngrok) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click>=8.1.3->Flask>=0.8->flask_ngrok) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Jinja2>=3.1.2->Flask>=0.8->flask_ngrok) (2.1.5)
# Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Installing collected packages: flask_ngrok
# Successfully installed flask_ngrok-0.0.25
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\vbala\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#      ---------------------------------------- 0.1/100.1 MB 1.7 MB/s eta 0:01:01
#      ---------------------------------------- 0.2/100.1 MB 2.2 MB/s eta 0:00:45
#      ---------------------------------------- 0.5/100.1 MB 4.5 MB/s eta 0:00:23
#      ---------------------------------------- 1.0/100.1 MB 7.2 MB/s eta 0:00:14
#       -------------------------------------- 2.0/100.1 MB 10.3 MB/s eta 0:00:10
#      - ------------------------------------- 2.7/100.1 MB 12.5 MB/s eta 0:00:08
#      - ------------------------------------- 3.6/100.1 MB 14.3 MB/s eta 0:00:07
#      - ------------------------------------- 4.3/100.1 MB 14.6 MB/s eta 0:00:07
#      -- ------------------------------------ 5.2/100.1 MB 15.9 MB/s eta 0:00:06
#      -- ------------------------------------ 6.1/100.1 MB 16.1 MB/s eta 0:00:06
#      -- ------------------------------------ 6.9/100.1 MB 17.0 MB/s eta 0:00:06
#      -- ------------------------------------ 7.7/100.1 MB 17.0 MB/s eta 0:00:06
#      --- ----------------------------------- 8.5/100.1 MB 17.5 MB/s eta 0:00:06
#      --- ----------------------------------- 9.4/100.1 MB 18.1 MB/s eta 0:00:06
#      --- ---------------------------------- 10.2/100.1 MB 18.1 MB/s eta 0:00:05
#      ---- --------------------------------- 11.0/100.1 MB 22.6 MB/s eta 0:00:04
#      ---- --------------------------------- 11.9/100.1 MB 21.8 MB/s eta 0:00:05
#      ---- --------------------------------- 12.7/100.1 MB 21.8 MB/s eta 0:00:05
#      ----- -------------------------------- 13.6/100.1 MB 21.8 MB/s eta 0:00:04
#      ----- -------------------------------- 14.4/100.1 MB 21.8 MB/s eta 0:00:04
#      ----- -------------------------------- 15.2/100.1 MB 22.6 MB/s eta 0:00:04
#      ------ ------------------------------- 16.0/100.1 MB 21.9 MB/s eta 0:00:04
#      ------ ------------------------------- 16.8/100.1 MB 21.8 MB/s eta 0:00:04
#      ------ ------------------------------- 17.6/100.1 MB 21.9 MB/s eta 0:00:04
#      ------- ------------------------------ 18.5/100.1 MB 21.8 MB/s eta 0:00:04
#      ------- ------------------------------ 19.3/100.1 MB 21.8 MB/s eta 0:00:04
#      ------- ------------------------------ 20.2/100.1 MB 21.8 MB/s eta 0:00:04
#      ------- ------------------------------ 21.1/100.1 MB 21.8 MB/s eta 0:00:04
#      -------- ----------------------------- 22.3/100.1 MB 21.8 MB/s eta 0:00:04
#      -------- ----------------------------- 23.1/100.1 MB 22.6 MB/s eta 0:00:04
#      --------- ---------------------------- 23.9/100.1 MB 21.8 MB/s eta 0:00:04
#      --------- ---------------------------- 24.8/100.1 MB 22.6 MB/s eta 0:00:04
#      --------- ---------------------------- 25.6/100.1 MB 21.8 MB/s eta 0:00:04
#      ---------- --------------------------- 26.4/100.1 MB 21.8 MB/s eta 0:00:04
#      ---------- --------------------------- 27.3/100.1 MB 21.8 MB/s eta 0:00:04
#      ---------- --------------------------- 28.1/100.1 MB 21.8 MB/s eta 0:00:04
#      ---------- --------------------------- 28.9/100.1 MB 21.8 MB/s eta 0:00:04
#      ----------- -------------------------- 29.8/100.1 MB 21.9 MB/s eta 0:00:04
#      ----------- -------------------------- 30.6/100.1 MB 22.5 MB/s eta 0:00:04
#      ----------- -------------------------- 31.5/100.1 MB 22.6 MB/s eta 0:00:04
#      ------------ ------------------------- 32.3/100.1 MB 21.9 MB/s eta 0:00:04
#      ------------ ------------------------- 33.2/100.1 MB 21.8 MB/s eta 0:00:04
#      ------------ ------------------------- 34.0/100.1 MB 22.6 MB/s eta 0:00:03
#      ------------- ------------------------ 34.8/100.1 MB 21.8 MB/s eta 0:00:03
#      ------------- ------------------------ 35.7/100.1 MB 21.8 MB/s eta 0:00:03
#      ------------- ------------------------ 36.4/100.1 MB 22.6 MB/s eta 0:00:03
#      -------------- ----------------------- 37.3/100.1 MB 21.8 MB/s eta 0:00:03
#      -------------- ----------------------- 38.1/100.1 MB 21.9 MB/s eta 0:00:03
#      -------------- ----------------------- 39.0/100.1 MB 21.8 MB/s eta 0:00:03
#      --------------- ---------------------- 39.9/100.1 MB 21.8 MB/s eta 0:00:03
#      --------------- ---------------------- 40.7/100.1 MB 21.9 MB/s eta 0:00:03
#      --------------- ---------------------- 41.3/100.1 MB 21.8 MB/s eta 0:00:03
#      ---------------- --------------------- 42.6/100.1 MB 21.8 MB/s eta 0:00:03
#      ---------------- --------------------- 43.6/100.1 MB 21.9 MB/s eta 0:00:03
#      ---------------- --------------------- 44.2/100.1 MB 21.1 MB/s eta 0:00:03
#      ----------------- -------------------- 44.9/100.1 MB 20.5 MB/s eta 0:00:03
#      ----------------- -------------------- 45.5/100.1 MB 19.8 MB/s eta 0:00:03
#      ----------------- -------------------- 47.3/100.1 MB 21.8 MB/s eta 0:00:03
#      ------------------ ------------------- 48.1/100.1 MB 21.8 MB/s eta 0:00:03
#      ------------------ ------------------- 49.0/100.1 MB 21.8 MB/s eta 0:00:03
#      ------------------ ------------------- 49.7/100.1 MB 20.5 MB/s eta 0:00:03
#      ------------------- ------------------ 51.2/100.1 MB 22.6 MB/s eta 0:00:03
#      ------------------- ------------------ 52.0/100.1 MB 22.6 MB/s eta 0:00:03
#      -------------------- ----------------- 52.9/100.1 MB 22.6 MB/s eta 0:00:03
#      -------------------- ----------------- 53.7/100.1 MB 21.8 MB/s eta 0:00:03
#      -------------------- ----------------- 54.5/100.1 MB 23.4 MB/s eta 0:00:02
#      -------------------- ----------------- 55.3/100.1 MB 23.4 MB/s eta 0:00:02
#      --------------------- ---------------- 56.3/100.1 MB 23.4 MB/s eta 0:00:02
#      --------------------- ---------------- 57.2/100.1 MB 21.9 MB/s eta 0:00:02
#      ---------------------- --------------- 58.0/100.1 MB 22.5 MB/s eta 0:00:02
#      ---------------------- --------------- 58.9/100.1 MB 21.9 MB/s eta 0:00:02
MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------- 100.1/100.1 MB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Click>=6.0 in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from face_recognition) (8.1.7)
# Collecting dlib>=19.7 (from face_recognition)
#   Downloading dlib-19.24.6.tar.gz (3.4 MB)
#      ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#      - -------------------------------------- 0.2/3.4 MB ? eta -:--:--
#      ----------- ---------------------------- 0.9/3.4 MB 14.6 MB/s eta 0:00:01
#      -------------------------------- ------- 2.8/3.4 MB 29.4 MB/s eta 0:00:01
#      ---------------------------------------  3.4/3.4 MB 26.9 MB/s eta 0:00:01
#      ---------------------------------------- 3.4/3.4 MB 23.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from face_recognition) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from face_recognition) (10.3.0)
# Requirement already satisfied: colorama in c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Click>=6.0->face_recognition) (0.4.6)
# Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: dlib, face-recognition-models
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
#   Building wheel for face-recognition-models (setup.py): started
#   Building wheel for face-recognition-models (setup.py): finished with status 'done'
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566177 sha256=b855f817b22caf764baf02899b3e3cc4142e30b5aa33072c2bedc5ac4beeaaaa
#   Stored in directory: c:\users\vbala\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\8f\47\c8\f44c5aebb7507f7c8a2c0bd23151d732d0f0bd6884ad4ac635
# Successfully built face-recognition-models
# Failed to build dlib
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [47 lines of output]
#       C:\Users\vbala\AppData\Local\Temp\pip-install-vaywv7yb\dlib_b85c0087226d4eada20552ef7e179400\setup.py:234: SyntaxWarning: invalid escape sequence '\('
#         major = re.findall("set\(CPACK_PACKAGE_VERSION_MAJOR.*\"(.*)\"", open(cmake_file).read())[0]
#       C:\Users\vbala\AppData\Local\Temp\pip-install-vaywv7yb\dlib_b85c0087226d4eada20552ef7e179400\setup.py:235: SyntaxWarning: invalid escape sequence '\('
#         minor = re.findall("set\(CPACK_PACKAGE_VERSION_MINOR.*\"(.*)\"", open(cmake_file).read())[0]
#       C:\Users\vbala\AppData\Local\Temp\pip-install-vaywv7yb\dlib_b85c0087226d4eada20552ef7e179400\setup.py:236: SyntaxWarning: invalid escape sequence '\('
#         patch = re.findall("set\(CPACK_PACKAGE_VERSION_PATCH.*\"(.*)\"", open(cmake_file).read())[0]
#       running bdist_wheel
#       running build
#       running build_ext
#
#       ================================================================================
#       ================================================================================
#       ================================================================================
#
#                          CMake is not installed on your system!
#
#           Or it is possible some broken copy of cmake is installed on your system.
#           It is unfortunately very common for python package managers to include
#           broken copies of cmake.  So if the error above this refers to some file
#           path to a cmake file inside a python or anaconda or miniconda path then you
#           should delete that broken copy of cmake from your computer.
#
#           Instead, please get an official copy of cmake from one of these known good
#           sources of an official cmake:
#               - cmake.org (this is how windows users should get cmake)
#               - apt install cmake (for Ubuntu or Debian based systems)
#               - yum install cmake (for Redhat or CenOS based systems)
#
#           On a linux machine you can run `which cmake` to see what cmake you are
#           actually using.  If it tells you it's some cmake from any kind of python
#           packager delete it and install an official cmake.
#
#           More generally, cmake is not installed if when you open a terminal window
#           and type
#              cmake --version
#           you get an error.  So you can use that as a very basic test to see if you
#           have cmake installed.  That is, if cmake --version doesn't run from the
#           same terminal window from which you are reading this error message, then
#           you have not installed cmake.  Windows users should take note that they
#           need to tell the cmake installer to add cmake to their PATH.  Since you
#           can't run commands that are not in your PATH.  This is how the PATH works
#           on Linux as well, but failing to add cmake to the PATH is a particularly
#           common problem on windows and rarely a problem on Linux.
#
#       ================================================================================
#       ================================================================================
#       ================================================================================
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
# ERROR: Could not build wheels for dlib, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\vbala\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
% cd "/content/drive/MyDrive/Final project/Website"
# !ls
# Out:
# /content/drive/MyDrive/Final project/Website
# 'Flask API.ipynb'  'Flask app .py'   model   static

# %% [markdown]
# #  Import libraries

# %%
from flask import Flask, render_template, request, redirect, url_for
from keras.models import load_model
import numpy as np
import cv2
import os
from flask import Flask
from werkzeug.utils import secure_filename
import os
from tensorflow import keras
from flask import Flask, request, render_template
from werkzeug.utils import secure_filename
import dlib
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from pyngrok import ngrok
from flask_ngrok import run_with_ngrok

# %% [markdown]
# # Display Home Page

# %%
 

app = Flask(__name__ , template_folder='static/templates')
ngrok.set_auth_token("29AhNyFJiBxEu0s07cR2zA8VqDQ_3wmwNStUSaHgpCiP2UNkd")
run_with_ngrok(app)
@app.route('/')
def main():
  return render_template ("Home.html")

# %% [markdown]
# #  Redirect To Upload

# %%
@app.route('/upload_video', methods=['POST'])
def Video():
  return render_template ("Upload_Video.html")

@app.route('/upload_image', methods=['POST'])
def image():
    return render_template('Upload_image.html')
@app.route('/About-us', methods=['POST'])
def About_us():
  return render_template('About-us.html')

# %% [markdown]
# # Load Model

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Final project/Website/model/deepfake-detection-tensor.h5')

# %% [markdown]
# # Function Prediction

# %%
def prediction (filepath):
  input_shape = (128, 128, 3)
  pr_data = []
  detector = dlib.get_frontal_face_detector()
  cap = cv2.VideoCapture(filepath)
  frameRate = cap.get(5)
  while cap.isOpened():
      frameId = cap.get(1)
      ret, frame = cap.read()
      if ret != True:
          break
      if frameId % ((int(frameRate)+1)*1) == 0:
          face_rects, scores, idx = detector.run(frame, 0)
          for i, d in enumerate(face_rects):
              x1 = d.left()
              y1 = d.top()
              x2 = d.right()
              y2 = d.bottom()
              crop_img = frame[y1:y2, x1:x2]
              data = img_to_array(cv2.resize(crop_img, (128, 128))).flatten() / 255.0
              data = data.reshape(-1, 128, 128, 3)
              print((model.predict(data) > 0.5).astype("int32"))
              outt=''
  if ((model.predict(data) > 0.5).astype("int32")[0][0] == 0 ):
    return 'Real'
  else:
    return'Fake'

# %% [markdown]
# # Upload File

# %%
UPLOAD_FOLDER = 'static'
app.secret_key = "secret key"
app.config['UPLOAD_FOLDER'] = UPLOAD_FOLDER
app.config['MAX_CONTENT_LENGTH'] = 16 * 1024 * 1024

# %% [markdown]
# #  Video Prediction & Display Result

# %%
@app.route('/predict_video', methods=['POST'])
def upload_video():
	file = request.files['file']
	filename = secure_filename(file.filename)
	file.save(os.path.join(app.config['UPLOAD_FOLDER'], filename))
	filepath = "static/"+filename
	preds = prediction(filepath)
	return render_template("Display_Video.html",prediction =preds ,video_path = filename)

# %% [markdown]
# # Image Prediction & Display Result

# %%
@app.route('/Predict_image', methods=['GET', 'POST'])
def upload():
    if request.method == 'POST':
        f = request.files['file']
        file_path = os.path.join (app.config['UPLOAD_FOLDER'], secure_filename(f.filename))
        f.save(file_path)
        # Make prediction
        preds = prediction(file_path)
    return render_template("Display_image.html",prediction = preds, img_path= f.filename )

# %% [markdown]
# # **Run Flask Application**#

# %%
if __name__ =='__main__': 
  app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://70d1-34-91-229-211.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [18/Jul/2022 10:14:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jul/2022 10:14:30] "GET /static/css/normalize.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jul/2022 10:14:30] "GET /static/css/main.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jul/2022 10:14:31] "GET /static/background/cover.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [18/Jul/2022 10:14:32] "GET /static/background/cover.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [18/Jul/2022 10:14:33] "GET /static/background/cover.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [18/Jul/2022 10:14:33] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Jul/2022 10:23:18] "POST /upload_image HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jul/2022 10:23:18] "POST /upload_image HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jul/2022 10:23:20] "GET /static/js/main.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jul/2022 10:23:20] "GET /static/js/jquery-1.12.4.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jul/2022 10:23:20] "GET /static/css/aa.jpg HTTP/1.1" 200 -
# [[1 0]]
# 127.0.0.1 - - [18/Jul/2022 10:25:34] "POST /Predict_image HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jul/2022 10:25:34] "GET /static/f.jpg HTTP/1.1" 200 -
